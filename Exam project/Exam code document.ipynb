# %% [markdown]
# # Exam project

# %% [markdown]
# Notice:
#
# *In order to import scraping_class, the module must be installed using pip install scraping_class in the anaconda prompt*

# %% [markdown]
# #### Import modules, and create logfile

# %%
import pandas as pd
import numpy as np
import requests
import scraping_class
from bs4 import BeautifulSoup
import html5lib
import csv
logfile = 'log.csv' ## name of log file.
connector = scraping_class.Connector(logfile)

# %%
url = "http://karakterstatistik.stads.ku.dk/Histogram/SFAK18001E/Winter-2018/B1"
r = requests.get(url)

soup = BeautifulSoup(r.content, "html5lib")
print(soup.prettify())

quotes = []
table = soup.find('div', attrs = {'id':'container'})    

for row in table.findAll('div', attrs ={'class':'quote'}):
    quote = {}
    quote['']
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Karakterfordeling
#   </title>
#   <link href="/Content/Images/favicon.png" rel="icon" type="image/png"/>
#   <link href="/Content/Reset.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Common.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Header.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Menu.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Body.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Content.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Boxes.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/Language.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/KU_Override.css" rel="stylesheet" type="text/css"/>
#   <link href="/Content/jquery.treeview.css" rel="stylesheet" type="text/css"/>
#   <script src="/Scripts/jquery-1.5.1.js" type="text/javascript">
#   </script>
#   <script src="/Scripts/Treeview/jquery.treeview.js" type="text/javascript">
#   </script>
#   <script src="/Scripts/Treeview/jquery.cookie.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div class="page" id="Page">
#    <header>
#     <div id="header_name">
#      <a href="http://ku.dk">
#       <img alt="" src="/content/images/brand_ku.gif"/>
#      </a>
#     </div>
#     <div class="header_logo">
#      <a href="/">
#       <img alt="" src="/content/images/logo.gif"/>
#       <img alt="" src="/content/images/navnetraek.gif"/>
#      </a>
#     </div>
#     <div class="header_logobottom">
#      <img alt="" src="/content/images/logoBottom.gif"/>
#     </div>
#    </header>
#    <section id="main">
#     <div id="FrontpageMain">
#      <div id="Content">
#       <div style="display: table;width:100%">
#        <div style="display: table-cell; padding-left: 15px; width: 100%">
#         <div style="border-top: solid 1px #901A1E; border-bottom:solid 1px #D5D5D5;background-color:#F2F2F2; padding:3px 2px 3px 5px; font-weight: bold; color: #5E5E5E;width:100%">
#          Karakterfordeling
#         </div>
#         <style>
#          td
#     {
#         border: 0px;
#     }
#         </style>
#         <form id="karsumForm" runat="server">
#          <a id="top">
#          </a>
#          <h2>
#           Toxicology and Drug Safety
#          </h2>
#          <table>
#           <tbody>
#            <tr>
#             <td style="padding-right: 2em">
#              Fakultet
#             </td>
#             <td>
#              Det Sundhedsvidenskabelige Fakultet
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Institut
#             </td>
#             <td>
#              Farmaci
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Termin
#             </td>
#             <td>
#              v18/B1
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              ECTS
#             </td>
#             <td>
#              5
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Andre versioner
#             </td>
#             <td>
#              <a href="http://karakterstatistik.stads.ku.dk/Histogram/SFAK18001E/Winter-2018/B1-1" style="padding-right: 3px;">
#               v18/B1
#              </a>
#             </td>
#            </tr>
#            <tr>
#             <td>
#              <br/>
#             </td>
#            </tr>
#            <tr>
#             <th colspan="2">
#              Ordinær eksamen
#             </th>
#             <td>
#             </td>
#             <th colspan="2">
#              Reeksamen
#             </th>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Antal tilmeldte
#             </td>
#             <td>
#              163
#             </td>
#             <td rowspan="5" style="width:20px">
#             </td>
#             <td style="padding-right: 2em">
#              Antal tilmeldte
#             </td>
#             <td>
#              16
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Fremmødte
#             </td>
#             <td>
#              160
#             </td>
#             <td style="padding-right: 2em">
#              Fremmødte
#             </td>
#             <td>
#              16
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Antal bestået
#             </td>
#             <td>
#              144                    (88                    %
# af de tilmeldte,
# 90                    %
# af de fremmødte                    )
#             </td>
#             <td style="padding-right: 2em">
#              Antal bestået
#             </td>
#             <td>
#              13                    (81                    %
# af de tilmeldte,
# 81                    %
# af de fremmødte)
#             </td>
#            </tr>
#            <tr>
#             <td style="padding-right: 2em">
#              Eksamensgennemsnit
#             </td>
#             <td>
#              5,5 (Efter 7-trinsskalaen)
#             </td>
#             <td style="padding-right: 2em">
#              Eksamensgennemsnit
#             </td>
#             <td>
#              2,4 (Efter 7-trinsskalaen)
#             </td>
#            </tr>
#            <tr>
#             <td colspan="2">
#              <table style="width: 100%;">
#               <tbody>
#                <tr>
#                 <td style="width: 50%;">
#                  <h3>
#                   Resultater
#                  </h3>
#                  <table>
#                   <tbody>
#                    <tr>
#                     <th>
#                      Karakter
#                     </th>
#                     <th colspan="2">
#                      Antal
#                     </th>
#                    </tr>
#                    <tr>
#                     <td>
#                      12
#                     </td>
#                     <td style="text-align: center">
#                      3
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="1,8 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="1"/>
#                      (1,8 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      10
#                     </td>
#                     <td style="text-align: center">
#                      35
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="21,5 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="21"/>
#                      (21,5 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      7
#                     </td>
#                     <td style="text-align: center">
#                      44
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="27 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="26"/>
#                      (27,0 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      4
#                     </td>
#                     <td style="text-align: center">
#                      38
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="23,3 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="23"/>
#                      (23,3 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      02
#                     </td>
#                     <td style="text-align: center">
#                      24
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="14,7 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="14"/>
#                      (14,7 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      00
#                     </td>
#                     <td style="text-align: center">
#                      13
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="8 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="7"/>
#                      (8,0 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      -3
#                     </td>
#                     <td style="text-align: center">
#                      3
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="1,8 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="1"/>
#                      (1,8 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      Ej mødt
#                     </td>
#                     <td style="text-align: center">
#                      3
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="1,8 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="1"/>
#                      (1,8 %)
#                     </td>
#                    </tr>
#                   </tbody>
#                  </table>
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </td>
#             <td colspan="2">
#              <table style="width: 100%;">
#               <tbody>
#                <tr>
#                 <td style="width: 50%;">
#                  <h3>
#                   Resultater
#                  </h3>
#                  <table>
#                   <tbody>
#                    <tr>
#                     <th>
#                      Karakter
#                     </th>
#                     <th colspan="2">
#                      Antal
#                     </th>
#                    </tr>
#                    <tr>
#                     <td>
#                      12
#                     </td>
#                     <td style="text-align: center">
#                      0
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      (0,0 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      10
#                     </td>
#                     <td style="text-align: center">
#                      1
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="6,2 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="6"/>
#                      (6,2 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      7
#                     </td>
#                     <td style="text-align: center">
#                      0
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      (0,0 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      4
#                     </td>
#                     <td style="text-align: center">
#                      2
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="12,5 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="12"/>
#                      (12,5 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      02
#                     </td>
#                     <td style="text-align: center">
#                      10
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="62,5 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="62"/>
#                      (62,5 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      00
#                     </td>
#                     <td style="text-align: center">
#                      3
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      <img alt="18,8 %" height="12" src="http://karakterstatistik.stads.ku.dk/Content/BarPixel.gif" style="vertical-align: top;" width="18"/>
#                      (18,8 %)
#                     </td>
#                    </tr>
#                    <tr>
#                     <td>
#                      -3
#                     </td>
#                     <td style="text-align: center">
#                      0
#                     </td>
#                     <td style="vertical-align: top; text-align: left;">
#                      (0,0 %)
#                     </td>
#                    </tr>
#                   </tbody>
#                  </table>
#                 </td>
#                </tr>
#               </tbody>
#              </table>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#          <br/>
#          <br/>
#          <a href="javascript: history.go(-1)">
#           Tilbage
#          </a>
#          |
#          <a href="/">
#           Ny søgning
#          </a>
#         </form>
#        </div>
#       </div>
#      </div>
#     </div>
#    </section>
#    <footer>
#     <div style="color: #666; font-family: Verdana, Arial, Helvetica, sans-serif; font-size: 10px;">
#      Support: tlf: +45 45 25 73 77
#      <img alt="" src="/Content/images/dot.gif"/>
#      E-mail:
#      <a href="mailto:ku@arcanicsupport.dk">
#       ku@arcanicsupport.dk
#      </a>
#     </div>
#    </footer>
#   </div>
#  </body>
# </html>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f36255230e66> in <module>()
#       8 table = soup.find('div', attrs = {'id':'container'})
#       9
# ---> 10 for row in table.findAll('div', attrs ={'class':'quote'}):
#      11     quote = {}
#      12     quote['']
#
# AttributeError: 'NoneType' object has no attribute 'findAll'
