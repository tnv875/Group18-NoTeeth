# %%
import scraping_class
logfile = 'log.txt'## name your log file.
connector = scraping_class.Connector(logfile)
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook

# %%
import pandas as pd
import numpy as np
import html5lib
import sys
import pickle
from tqdm import tqdm_notebook

# %%
with open('df_final.pkl', 'rb') as f:
    df = pickle.load(f)

# %% [markdown]
# ## Defining function to look into statistics

# %%
def tlen(name):
    tlen = pd.DataFrame()
    tlen_id = []
    tlen_value = []
    tlen_share = []
    for i in df[name].unique():
        tlen_id.append(i)
        tlen_value.append(len(df.loc[df[name] == i]))
        
    for i in df[name].unique():
        tlen_share.append((len(df.loc[df[name] == i])/sum(tlen_value)*100))
        
    tlen_id.append('Total')
    tlen_value.append(sum(tlen_value))
    tlen_share.append(sum(tlen_share))
        
        
    tlen['Id'] = tlen_id
    tlen['Value'] = tlen_value
    tlen['Share %'] = tlen_share
        
    return(tlen.sort_values('Value',ascending=True))

# %%
def tlen_year(name,year):
    df1 = df[df['Year'] == year]
    tlen = pd.DataFrame()
    tlen_id = []
    tlen_value = []
    tlen_share = []
    for i in df[name].unique():
        tlen_id.append(i)
        tlen_value.append(len(df1.loc[df[name] == i]))
    
    for i in df[name].unique():
        tlen_share.append((len(df1.loc[df[name] == i])/sum(tlen_value)*100))
        
    tlen_id.append('Total')
    tlen_value.append(sum(tlen_value))
    tlen_share.append(sum(tlen_share))
        
    tlen['Id'] = tlen_id
    tlen['Value'] = tlen_value
    tlen['Share %'] = tlen_share
        
    return(tlen.sort_values('Value',ascending=True))

# %%
def tlen_byyear(name):
    
    tlen = pd.DataFrame()
    my_dict = {}
    for i in df[name].unique():
        my_dict['Id'] = i
        for k in df['Year'].unique():
            my_dict
        
        df1 = df[df['Year'] == '2013-2014']
        tlen_1314.append(len(df1.loc[df[name] == i]))
        df2 = df[df['Year'] == '2014-2015']
        tlen_1415.append(len(df2.loc[df[name] == i]))
        df3 = df[df['Year'] == '2015-2016']
        tlen_1516.append(len(df3.loc[df[name] == i]))
        df4 = df[df['Year'] == '2016-2017']
        tlen_1617.append(len(df4.loc[df[name] == i]))
        df5 = df[df['Year'] == '2017-2018']
        tlen_1718.append(len(df5.loc[df[name] == i]))
    
    
        
    tlen_id.append('Total')
    tlen_value.append(sum(tlen_value))
    tlen_share.append(sum(tlen_share))
        
    tlen['Id'] = tlen_id
    tlen[''2013-2014''] = tlen_value
    tlen['Share %'] = tlen_share
        
    return(tlen.sort_values('Value',ascending=True))

# %%
def tlen_byyear(name):
    
    tlen = pd.DataFrame()
    tlen_id = []
    tlen_1314 = []
    tlen_1415 = []
    tlen_1516 = []
    tlen_1617 = []
    tlen_1718 = []

    for i in df[name].unique():
        tlen_id.append(i)
        df1 = df[df['Year'] == '2013-2014']
        tlen_1314.append(len(df1.loc[df[name] == i]))
        df2 = df[df['Year'] == '2014-2015']
        tlen_1415.append(len(df2.loc[df[name] == i]))
        df3 = df[df['Year'] == '2015-2016']
        tlen_1516.append(len(df3.loc[df[name] == i]))
        df4 = df[df['Year'] == '2016-2017']
        tlen_1617.append(len(df4.loc[df[name] == i]))
        df5 = df[df['Year'] == '2017-2018']
        tlen_1718.append(len(df5.loc[df[name] == i]))
    
    
        
    tlen_id.append('Total')
    tlen_1314.append(sum(tlen_1314))
    tlen_1415.append(sum(tlen_1415))
    tlen_1516.append(sum(tlen_1516))
    tlen_1617.append(sum(tlen_1617))
    tlen_1718.append(sum(tlen_1718))
    
        
    tlen['Id'] = tlen_id
    tlen['2013-2014'] = tlen_1314
    tlen['2014-2015'] = tlen_1415
    tlen['2015-2016'] = tlen_1516
    tlen['2016-2017'] = tlen_1617
    tlen['2017-2018'] = tlen_1718
        
    return(tlen)

# %% [markdown]
# # Descriptive statistic - diving in to the weirds of the data
# ## Years
# It is seen from `tlen('year')` that there a many fewer eksamns in the study year 2013-2014 than the rest. By looking at `tlen_year('Termin','2013-2014')` it is seen that only the summer eksamns are in this year. By going to the grade web-page it is seen that it only tracks data to summer 14, and therefore eksamns from winter 13 not included.
#
# It is seen that apparently 2015-2016 has around 500 more eksamns than both the year before and the year after. Most of them are from HUM as seen in `tlen_byyear('Fakultet')`. F.eks. TORS has 150 in 2015-2016 and suddenly 1 in 2016-2017. It seems like 2015-2016 as seen by `tlen_byyear('Institut')` maybe there where an extra focus on doing statistics in 2016-2017. This hypothesis is backed up by `tlen_byyear('Censorship form_edit')` where the rise is shown in nan. I.E the courses where the info on the exam is limited.
#
# An Interesting fact from `tlen_byyear('Censorship form_edit')` is that no external is rising whil external is falling.

# %%
tlen_byyear('Institut')
# Out:
#                                                    Id  2013-2014  2014-2015  \
# 0                               Niels Bohr Institutet         58        125
# 1                          Institut for Statskundskab         64        101
# 2                      Statens Naturhistoriske Museum          9         28
# 3       Institut for Geovidenskab og Naturforvaltning         98        223
# 4       Institut for Medier, Erkendelse og Formidling         47         94
# 5   Saxo-Instituttet - Arkæologi, Etnologi, Histor...         34         45
# 6           Institut for Engelsk, Germansk og Romansk         19         69
# 7                                  Økonomisk Institut         84        167
# 8                                 Datalogisk Institut         32         79
# 9              Institut for Plante- og Miljøvidenskab         43         81
# 10                                 MSc Animal Science          3         13
# 11                                 Biologisk Institut         70        146
# 12                     MSc Immunologi og inflammation          0          0
# 13  Uddannelsesråd for veterinærvidenskab og husdy...          6         42
# 14                     Institut for Fødevarevidenskab         23         46
# 15         Institut for Fødevare- og Ressourceøkonomi         42         82
# 16                           Institut for antropologi          8         45
# 17                                    Kemisk Institut         39         95
# 18                               Sociologisk Institut         30         64
# 19                 Institut for Naturfagenes Didaktik          6          9
# 20                            MSc Lægemiddelvidenskab         11         42
# 21                             Folkesundhedsvidenskab         10         37
# 22                                                NaN          0          0
# 23  Den Sundhedsfaglige supplerings- og kandidatud...         10         20
# 24                        Master i Public Health (MA)          3         10
# 25                     Institut for Idræt og Ernæring         36         94
# 26                                            Farmaci         22         64
# 27                       Institut for Matematiske Fag         63        153
# 28                                   MSc Humanbiologi          4         11
# 29                  Studienævnet for Global Udvikling          0          7
# 30                                     Global Sundhed          3         10
# 31                     Studienævnet for Afrikastudier          1          6
# 32   Institut for Tværkulturelle og regionale studier         29         49
# 33              Institut for Kunst og Kulturvidenskab         37         66
# 34    Institut for Nordiske Studier og Sprogvidenskab         33         55
# 35                                            Medicin         70        158
# 36                                   Veterinærmedicin         51        113
# 37                             Institut for Psykologi         39         72
# 38                                         Odontologi         24         54
# 39                                                IVA         13         43
# 40          Masteruddannelse i lægemiddelregistrering          0          0
# 41                               Institut for Farmaci          0          1
# 42                               Molekylær biomedicin          7         25
# 43       Institut for Lægemiddeldesign og Farmakologi          2          2
# 44  Institut for Klinisk Veterinær- og Husdyrsvide...          1          2
# 45                 Master of Disaster Management (MA)          0          6
# 46                                      IT og sundhed          5         17
# 47            Juridisk Diplomuddannelse i Krimonologi          0          0
# 48              Institut for Veterinær Sygdomsbiologi          0          1
# 49                               Medicin og teknologi          6         17
# 50                               Miljøkemi og sundhed          0          1
# 51               Masteruddannelse i hovedpinesygdomme          0          0
# 52                 Master i International Health (MA)          0          3
# 53        Juridisk Masteruddannelse i Konfliktmægling          0          0
# 54               Institut for Produktionsdyr og Heste          0          2
# 55                                              Total       1195       2695
#
#     2015-2016  2016-2017  2017-2018
# 0         131        124        131
# 1         165        156        153
# 2          22         27         25
# 3         225        233        236
# 4         123        105         54
# 5          74         33         40
# 6         181        139        113
# 7         184        166        126
# 8          69         76         75
# 9          88         85         90
# 10         16         13         14
# 11        151        151        150
# 12          0          7         10
# 13         38         24         21
# 14         51         54         55
# 15        103         92         92
# 16         73         55         61
# 17         94         89         91
# 18         32         35         69
# 19         11         15         10
# 20         26         24         15
# 21         47         43         39
# 22          0          0          0
# 23         26         27         26
# 24         15         13         10
# 25         89         82         85
# 26         45         46         37
# 27        171        157        167
# 28          9         18         12
# 29          9          9          8
# 30         16         14         18
# 31         12          9         11
# 32        154          1          0
# 33         93         44         28
# 34         83          3          0
# 35        163        195        224
# 36         76         76         67
# 37         71         76         96
# 38         76         73         74
# 39         50         16          9
# 40          0          8         15
# 41          2          4          3
# 42         19         17         15
# 43          4          3          4
# 44          6          4          7
# 45          7          7         10
# 46         19         20         16
# 47          1          6          3
# 48          1          1          1
# 49         23         27         30
# 50          1          1          2
# 51          0          4          1
# 52          2          2          0
# 53          1          1          1
# 54          0          0          0
# 55       3148       2710       2650

# %%
tlen_byyear('Censorship form_edit')
# Out:
#                        Id  2013-2014  2014-2015  2015-2016  2016-2017  \
# 0  No external censorship        603       1448       1598       1664
# 1     External censorship        547       1245       1295       1120
# 2                     nan        196        347        634        285
# 3                   Total       1346       3040       3527       3069
#
#    2017-2018
# 0       1814
# 1        993
# 2        195
# 3       3002

# %%
list_1 = df[df['Year'] == '2014-2015']['ID'].to_list()
list_2 = df[df['Year'] == '2015-2016']['ID'].to_list()
list_3 = df[df['Year'] == '2016-2017']['ID'].to_list()
list_4 = df[df['Year'] == '2017-2018']['ID'].to_list()

list_5 = []
for i in list_3:
    if i not in list_4:
        list_5.append(i)

len(list_5)
# Out:
# 907

# %%
tlen_byyear('Kursus')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-165-5ccdc1efd6ff> in <module>
# ----> 1 tlen_byyear('Kursus')
#
# <ipython-input-150-aa2c9d3bf0a6> in tlen_byyear(name)
#      11     for i in df[name].unique():
#      12         tlen_id.append(i)
# ---> 13         df1 = df[df['Year'] == '2013-2014']
#      14         tlen_1314.append(len(df1.loc[df[name] == i]))
#      15         df2 = df[df['Year'] == '2014-2015']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
# -> 2969         return self._take(indexer, axis=0)
#    2970
#    2971     def _getitem_multilevel(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    3357         new_data = self._data.take(indices,
#    3358                                    axis=self._get_block_manager_axis(axis),
# -> 3359                                    verify=True)
#    3360         result = self._constructor(new_data).__finalize__(self)
#    3361
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1348         new_labels = self.axes[axis].take(indexer)
#    1349         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 1350                                     axis=axis, allow_dups=True)
#    1351
#    1352     def merge(self, other, lsuffix='', rsuffix=''):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1236             fill_value = fill_tuple[0]
#    1237             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1238                                        allow_fill=True, fill_value=fill_value)
#    1239
#    1240         if new_mgr_locs is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1649             out = np.empty(out_shape, dtype=dtype, order='F')
#    1650         else:
# -> 1651             out = np.empty(out_shape, dtype=dtype)
#    1652
#    1653     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# KeyboardInterrupt:

# %%
for i in range(len(df['Year'])):
    if df['Year'][i] == '2014-2015':
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-164-1a9326f675e8> in <module>
#       1 for i in df:
# ----> 2     if df['Year'] == '2014-2015':
#       3         print(df)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1478                          .format(self.__class__.__name__))
#    1479
#    1480     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
tlen_year('Fakultet','2014-2015')
# Out:
#                                          Id  Value     Share %
# 5                   Det Teologiske Fakultet     82    2.697368
# 4                    Det Juridiske Fakultet    269    8.848684
# 2                 Det Humanistiske Fakultet    421   13.848684
# 1       Det Samfundsvidenskabelige Fakultet    456   15.000000
# 3       Det Sundhedsvidenskabelige Fakultet    651   21.414474
# 0  Det Natur- og Biovidenskabelige Fakultet   1161   38.190789
# 6                                     Total   3040  100.000000

# %%
print(df.columns.values)
# Out:
# ['Kursus' 'Fakultet' 'Institut' 'Termin' 'ECTS' 'Eksamenstype'
#  'Antal tilmeldte' 'Fremmødte' 'Antal bestået' 'Eksamensgennemsnit' 12 10
#  7 4 2 0 -3 'Ej mødt' 'Ikke bestået' 'Year' 'ID' 'Re-exam_dummy' 'URL_E'
#  'level_0' 'Course Name' 'Credit' 'Type of assessment' 'Aid'
#  'Marking scale' 'Censorship form' 'Exam period' 'Re-exam' 'Language'
#  'Course code' 'Level' 'Duration' 'Placement' 'Schedule' 'Study board'
#  'Course id' 'Category' 'Lectures' 'Preparation' 'Exam' 'Total' 'Content'
#  'Learning\r\nOutcome' 'Class Instruction' 'Practical exercises'
#  'Exam registration requirements' 'Field Work' 'Course capacity' 'Seminar'
#  'Guidance' 'Continuing and further education' 'Price' 'Class Seminar'
#  'Class Exercises' 'Study Groups' 'Exercises' 'Exam Preparation'
#  'Excursions' 'Øvelseshold' 'Øvelser' 'Course Preparation'
#  'Theory exercises' 'Project work' 'Clinical practice' 'Praktik'
#  'Colloquia' 'Laboratory' 'E-Learning' 'Practical Training' 'Praksishold'
#  'Tutoring' 'Manuduktion' 'Aid_edit' 'Marking scale_edit'
#  'Censorship form_edit' 'Bachelor' 'Bachelor choice'
#  'Full Degree Master choice' 'Full Degree Master' 'Propaedeutics'
#  'Part Time Master' 'Ph.D.' 'Professionsbachelor' 'Master' 'Duration_edit'
#  'Credit_edit' 'Lectures_edit' 'Preparation_edit' 'Exam_edit' 'Total_edit'
#  'Practical exercises_edit' 'Field Work_edit' 'Guidance_edit'
#  'Class Seminar_edit' 'Class Exercises_edit' 'Study Groups_edit'
#  'Exercises_edit' 'Exam Preparation_edit' 'Excursions_edit'
#  'Øvelseshold_edit' 'Øvelser_edit' 'Course Preparation_edit'
#  'Theory exercises_edit' 'Project work_edit' 'Clinical practice_edit'
#  'Praktik_edit' 'Colloquia_edit' 'Laboratory_edit' 'E-Learning_edit'
#  'Practical Training_edit' 'Praksishold_edit' 'Tutoring_edit'
#  'Manuduktion_edit' 'Language_edit' 'Type of assessmet_edit' 'URL_C']

# %%
pd.to_numeric(df['Antal tilmeldte']).describe()
# Out:
# count    13984.000000
# mean        47.915618
# std         73.119560
# min          4.000000
# 25%         12.000000
# 50%         24.000000
# 75%         49.000000
# max        773.000000
# Name: Antal tilmeldte, dtype: float64

# %%
tlen('Termin' )
# Out:
#         Id  Value
# 3      v15   1153
# 14     s16    985
# 2      v16    917
# 4      v14    913
# 21     v17    895
# 16     s15    851
# 15     s14    761
# 13     s17    755
# 1      s18    699
# 22  v17/B1    394
# 23  v16/B1    391
# 24  v15/B1    385
# 7   v14/B1    354
# 17  v17/B2    343
# 25  v16/B2    337
# 27  s16/B3    333
# 29  s18/B3    332
# 26  v15/B2    325
# 30  s17/B3    322
# 6   v14/B2    309
# 0   s15/B3    306
# 31  s14/B3    293
# 18  s17/B4    260
# 28  s18/B4    259
# 19  s16/B4    256
# 5   s15/B4    256
# 20  s14/B4    241
# 10  s16/B5     87
# 9   s17/B5     85
# 8   s18/B5     80
# 12  s14/B5     50
# 11  s15/B5     50
# 32  s16/B2      2
# 35  v16/B4      2
# 33  s15/B2      1
# 34  s14/B2      1
# 36  v15/B4      1

# %%
tlen('Year')
# Out:
#           Id  Value
# 0  2013-2014   1346

# %%
tlen('Fakultet')
# Out:
#                                          Id  Value
# 0  Det Natur- og Biovidenskabelige Fakultet    519
# 3       Det Sundhedsvidenskabelige Fakultet    238
# 2       Det Samfundsvidenskabelige Fakultet    225
# 1                 Det Humanistiske Fakultet    212
# 5                    Det Juridiske Fakultet    117
# 4                   Det Teologiske Fakultet     35

# %%
len(tlen('Institut'))
tlen('Institut')
# Out:
#                                                    Id  Value
# 3       Institut for Geovidenskab og Naturforvaltning   1015
# 35                                            Medicin    810
# 7                                  Økonomisk Institut    727
# 27                       Institut for Matematiske Fag    711
# 11                                 Biologisk Institut    668
# 1                          Institut for Statskundskab    639
# 0                               Niels Bohr Institutet    569
# 6           Institut for Engelsk, Germansk og Romansk    521
# 4       Institut for Medier, Erkendelse og Formidling    423
# 15         Institut for Fødevare- og Ressourceøkonomi    411
# 17                                    Kemisk Institut    408
# 9              Institut for Plante- og Miljøvidenskab    387
# 25                     Institut for Idræt og Ernæring    386
# 36                                   Veterinærmedicin    383
# 37                             Institut for Psykologi    354
# 8                                 Datalogisk Institut    331
# 38                                         Odontologi    301
# 33              Institut for Kunst og Kulturvidenskab    268
# 16                           Institut for antropologi    242
# 32   Institut for Tværkulturelle og regionale studier    233
# 18                               Sociologisk Institut    230
# 14                     Institut for Fødevarevidenskab    229
# 5   Saxo-Instituttet - Arkæologi, Etnologi, Histor...    226
# 26                                            Farmaci    214
# 21                             Folkesundhedsvidenskab    176
# 34    Institut for Nordiske Studier og Sprogvidenskab    174
# 39                                                IVA    131
# 13  Uddannelsesråd for veterinærvidenskab og husdy...    131
# 20                            MSc Lægemiddelvidenskab    118
# 2                      Statens Naturhistoriske Museum    111
# 23  Den Sundhedsfaglige supplerings- og kandidatud...    109
# 49                               Medicin og teknologi    103
# 42                               Molekylær biomedicin     83
# 46                                      IT og sundhed     77
# 30                                     Global Sundhed     61
# 10                                 MSc Animal Science     59
# 28                                   MSc Humanbiologi     54
# 24                        Master i Public Health (MA)     51
# 19                 Institut for Naturfagenes Didaktik     51
# 31                     Studienævnet for Afrikastudier     39
# 29                  Studienævnet for Global Udvikling     33
# 45                 Master of Disaster Management (MA)     30
# 40          Masteruddannelse i lægemiddelregistrering     23
# 44  Institut for Klinisk Veterinær- og Husdyrsvide...     20
# 12                     MSc Immunologi og inflammation     17
# 43       Institut for Lægemiddeldesign og Farmakologi     15
# 41                               Institut for Farmaci     10
# 47            Juridisk Diplomuddannelse i Krimonologi     10
# 52                 Master i International Health (MA)      7
# 50                               Miljøkemi og sundhed      5
# 51               Masteruddannelse i hovedpinesygdomme      5
# 48              Institut for Veterinær Sygdomsbiologi      4
# 53        Juridisk Masteruddannelse i Konfliktmægling      3
# 54               Institut for Produktionsdyr og Heste      2
# 22                                                NaN      0

# %%
pd.to_numeric(df['Eksamensgennemsnit']).describe()
# Out:
# count    11974.000000
# mean         6.939119
# std          2.289251
# min         -3.000000
# 25%          5.533333
# 50%          7.250000
# 75%          8.625000
# max         12.000000
# Name: Eksamensgennemsnit, dtype: float64

# %%
with open('df_final_outer-Copy1.pkl', 'rb') as f:
    dfo = pickle.load(f)

# %%
dfo[dfo['Year'] == '2013-2014']
# Out:
#                                                   Kursus  \
# 21                 §3 i praksis - Naturbeskyttelsesloven
# 27                                         1. årsprojekt
# 33                                          1.årsprojekt
# 34                              20. århundredes filosofi
# 35                                    306. Masterprojekt
# 40                               5. CCP1  Danish Culture
# 41                               6. CCP2  Danish Culture
# 42                               7. CCP3  Danish Culture
# 43          8. CCP4A  Intensive Course in Danish Culture
# 44          8. CCP4C  Intensive Course in Danish Culture
# 45           8. CCP4D Intensive Course in Danish Culture
# 46           8. CCP4D Intensive Course in Danish Culture
# 47          9. CCP4B  Intensive Course in Danish Culture
# 59                                      Academic English
# 81              Acceptance and Commitment Ther-apy (ACT)
# 87            Acquisition and Processing of Seismic Data
# 89     Adfærdsdesign og Offentlige Beslutningsprocess...
# 115           Adv. Development Economics - Micro Aspects
# 116           Adv. Development Economics - Micro Aspects
# 137              Advanced Algorithms and Data Structures
# 138              Advanced Algorithms and Data Structures
# 151                   Advanced Animal Production Science
# 170    Advanced Biotechnology and Intellectual Proper...
# 171    Advanced Biotechnology and Intellectual Proper...
# 194                         Advanced Conflict Management
# 257                              Advanced Food Chemistry
# 263     Advanced Health Promotion and Disease Prevention
# 266     Advanced Health Promotion and Disease Prevention
# 278                         Advanced Inorganic Chemistry
# 310                         Advanced language processing
# ...                                                  ...
# 28432                                                NaN
# 28433                                                NaN
# 28434                                                NaN
# 28435                                                NaN
# 28436                                                NaN
# 28437                                                NaN
# 28438                                                NaN
# 28439                                                NaN
# 28440                                                NaN
# 28441                                                NaN
# 28442                                                NaN
# 28443                                                NaN
# 28444                                                NaN
# 28445                                                NaN
# 28446                                                NaN
# 28447                                                NaN
# 28448                                                NaN
# 28449                                                NaN
# 28450                                                NaN
# 28451                                                NaN
# 28452                                                NaN
# 28453                                                NaN
# 28454                                                NaN
# 28455                                                NaN
# 28456                                                NaN
# 28457                                                NaN
# 28458                                                NaN
# 28459                                                NaN
# 28460                                                NaN
# 28461                                                NaN
#
#                                        Fakultet  \
# 21     Det Natur- og Biovidenskabelige Fakultet
# 27          Det Sundhedsvidenskabelige Fakultet
# 33                    Det Humanistiske Fakultet
# 34                    Det Humanistiske Fakultet
# 35                    Det Humanistiske Fakultet
# 40                    Det Humanistiske Fakultet
# 41                    Det Humanistiske Fakultet
# 42                    Det Humanistiske Fakultet
# 43                    Det Humanistiske Fakultet
# 44                    Det Humanistiske Fakultet
# 45                    Det Humanistiske Fakultet
# 46                    Det Humanistiske Fakultet
# 47                    Det Humanistiske Fakultet
# 59                    Det Humanistiske Fakultet
# 81          Det Samfundsvidenskabelige Fakultet
# 87     Det Natur- og Biovidenskabelige Fakultet
# 89          Det Samfundsvidenskabelige Fakultet
# 115         Det Samfundsvidenskabelige Fakultet
# 116         Det Samfundsvidenskabelige Fakultet
# 137    Det Natur- og Biovidenskabelige Fakultet
# 138    Det Natur- og Biovidenskabelige Fakultet
# 151         Det Sundhedsvidenskabelige Fakultet
# 170         Det Sundhedsvidenskabelige Fakultet
# 171         Det Sundhedsvidenskabelige Fakultet
# 194    Det Natur- og Biovidenskabelige Fakultet
# 257    Det Natur- og Biovidenskabelige Fakultet
# 263         Det Sundhedsvidenskabelige Fakultet
# 266         Det Sundhedsvidenskabelige Fakultet
# 278    Det Natur- og Biovidenskabelige Fakultet
# 310    Det Natur- og Biovidenskabelige Fakultet
# ...                                         ...
# 28432                                       NaN
# 28433                                       NaN
# 28434                                       NaN
# 28435                                       NaN
# 28436                                       NaN
# 28437                                       NaN
# 28438                                       NaN
# 28439                                       NaN
# 28440                                       NaN
# 28441                                       NaN
# 28442                                       NaN
# 28443                                       NaN
# 28444                                       NaN
# 28445                                       NaN
# 28446                                       NaN
# 28447                                       NaN
# 28448                                       NaN
# 28449                                       NaN
# 28450                                       NaN
# 28451                                       NaN
# 28452                                       NaN
# 28453                                       NaN
# 28454                                       NaN
# 28455                                       NaN
# 28456                                       NaN
# 28457                                       NaN
# 28458                                       NaN
# 28459                                       NaN
# 28460                                       NaN
# 28461                                       NaN
#
#                                                 Institut  Termin ECTS  \
# 21         Institut for Geovidenskab og Naturforvaltning  s14/B5    5
# 27                                Folkesundhedsvidenskab     s14   15
# 33         Institut for Medier, Erkendelse og Formidling     s14   75
# 34         Institut for Medier, Erkendelse og Formidling     s14   15
# 35         Institut for Medier, Erkendelse og Formidling     s14   15
# 40     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   75
# 41     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   75
# 42     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   15
# 43     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   15
# 44     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   15
# 45     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   15
# 46     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   15
# 47     Saxo-Instituttet - Arkæologi, Etnologi, Histor...     s14   15
# 59             Institut for Engelsk, Germansk og Romansk     s14   15
# 81                                Institut for Psykologi  s14/B5    5
# 87         Institut for Geovidenskab og Naturforvaltning  s14/B4   75
# 89                            Institut for Statskundskab     s14   10
# 115                                   Økonomisk Institut     s14   75
# 116                                   Økonomisk Institut     s14   75
# 137                                  Datalogisk Institut  s14/B4   75
# 138                                  Datalogisk Institut  s14/B4   75
# 151                                   MSc Animal Science  s14/B4   15
# 170    Uddannelsesråd for veterinærvidenskab og husdy...  s14/B4   15
# 171    Uddannelsesråd for veterinærvidenskab og husdy...     s14   15
# 194           Institut for Fødevare- og Ressourceøkonomi  s14/B4   75
# 257                       Institut for Fødevarevidenskab  s14/B4   75
# 263    Den Sundhedsfaglige supplerings- og kandidatud...     s14   75
# 266                          Master i Public Health (MA)     s14   75
# 278                                      Kemisk Institut  s14/B3   75
# 310                                  Datalogisk Institut  s14/B3   75
# ...                                                  ...     ...  ...
# 28432                                                NaN     NaN  NaN
# 28433                                                NaN     NaN  NaN
# 28434                                                NaN     NaN  NaN
# 28435                                                NaN     NaN  NaN
# 28436                                                NaN     NaN  NaN
# 28437                                                NaN     NaN  NaN
# 28438                                                NaN     NaN  NaN
# 28439                                                NaN     NaN  NaN
# 28440                                                NaN     NaN  NaN
# 28441                                                NaN     NaN  NaN
# 28442                                                NaN     NaN  NaN
# 28443                                                NaN     NaN  NaN
# 28444                                                NaN     NaN  NaN
# 28445                                                NaN     NaN  NaN
# 28446                                                NaN     NaN  NaN
# 28447                                                NaN     NaN  NaN
# 28448                                                NaN     NaN  NaN
# 28449                                                NaN     NaN  NaN
# 28450                                                NaN     NaN  NaN
# 28451                                                NaN     NaN  NaN
# 28452                                                NaN     NaN  NaN
# 28453                                                NaN     NaN  NaN
# 28454                                                NaN     NaN  NaN
# 28455                                                NaN     NaN  NaN
# 28456                                                NaN     NaN  NaN
# 28457                                                NaN     NaN  NaN
# 28458                                                NaN     NaN  NaN
# 28459                                                NaN     NaN  NaN
# 28460                                                NaN     NaN  NaN
# 28461                                                NaN     NaN  NaN
#
#           Eksamenstype Antal tilmeldte Fremmødte Antal bestået  \
# 21     Ordinær eksamen              12        12            12
# 27     Ordinær eksamen              59        59            59
# 33     Ordinær eksamen              64        60            60
# 34     Ordinær eksamen              69        67            59
# 35     Ordinær eksamen               9         9             9
# 40     Ordinær eksamen              97        97            89
# 41     Ordinær eksamen              45        39            37
# 42     Ordinær eksamen              11        10            10
# 43     Ordinær eksamen              37        31            27
# 44     Ordinær eksamen              45        44            44
# 45     Ordinær eksamen              39        33            26
# 46           Reeksamen               6         5             4
# 47     Ordinær eksamen              41        34            31
# 59     Ordinær eksamen              16        12            12
# 81     Ordinær eksamen              12        12            12
# 87     Ordinær eksamen              16        13            13
# 89     Ordinær eksamen              17        16            16
# 115    Ordinær eksamen              29        25            20
# 116          Reeksamen               7         5             5
# 137    Ordinær eksamen              69        45            39
# 138          Reeksamen              10         7             6
# 151    Ordinær eksamen               6         6             6
# 170    Ordinær eksamen              59        59            58
# 171    Ordinær eksamen              59        59            58
# 194    Ordinær eksamen              10         9             9
# 257    Ordinær eksamen              15        12            12
# 263    Ordinær eksamen               9         9             9
# 266    Ordinær eksamen               6         6             4
# 278    Ordinær eksamen              20        17            16
# 310    Ordinær eksamen              10         4             4
# ...                ...             ...       ...           ...
# 28432              NaN             NaN       NaN           NaN
# 28433              NaN             NaN       NaN           NaN
# 28434              NaN             NaN       NaN           NaN
# 28435              NaN             NaN       NaN           NaN
# 28436              NaN             NaN       NaN           NaN
# 28437              NaN             NaN       NaN           NaN
# 28438              NaN             NaN       NaN           NaN
# 28439              NaN             NaN       NaN           NaN
# 28440              NaN             NaN       NaN           NaN
# 28441              NaN             NaN       NaN           NaN
# 28442              NaN             NaN       NaN           NaN
# 28443              NaN             NaN       NaN           NaN
# 28444              NaN             NaN       NaN           NaN
# 28445              NaN             NaN       NaN           NaN
# 28446              NaN             NaN       NaN           NaN
# 28447              NaN             NaN       NaN           NaN
# 28448              NaN             NaN       NaN           NaN
# 28449              NaN             NaN       NaN           NaN
# 28450              NaN             NaN       NaN           NaN
# 28451              NaN             NaN       NaN           NaN
# 28452              NaN             NaN       NaN           NaN
# 28453              NaN             NaN       NaN           NaN
# 28454              NaN             NaN       NaN           NaN
# 28455              NaN             NaN       NaN           NaN
# 28456              NaN             NaN       NaN           NaN
# 28457              NaN             NaN       NaN           NaN
# 28458              NaN             NaN       NaN           NaN
# 28459              NaN             NaN       NaN           NaN
# 28460              NaN             NaN       NaN           NaN
# 28461              NaN             NaN       NaN           NaN
#
#       Eksamensgennemsnit  ... Colloquia_edit Laboratory_edit E-Learning_edit  \
# 21               9.16667  ...            0.0             0.0             0.0
# 27               9.40678  ...            NaN             NaN             NaN
# 33               7.16667  ...            NaN             NaN             NaN
# 34               6.08955  ...            NaN             NaN             NaN
# 35               9.44444  ...            NaN             NaN             NaN
# 40                   NaN  ...            NaN             NaN             NaN
# 41               8.66667  ...            NaN             NaN             NaN
# 42                  10.3  ...            NaN             NaN             NaN
# 43               7.58065  ...            0.0             0.0             0.0
# 44                  9.75  ...            0.0             0.0             0.0
# 45               6.93939  ...            0.0             0.0             0.0
# 46                     6  ...            0.0             0.0             0.0
# 47               8.97059  ...            0.0             0.0             0.0
# 59               8.83333  ...            0.0             0.0             0.0
# 81                   NaN  ...            NaN             NaN             NaN
# 87                   NaN  ...            0.0             0.0             0.0
# 89                   NaN  ...            0.0             0.0             0.0
# 115                 6.96  ...            NaN             NaN             NaN
# 116                  8.6  ...            NaN             NaN             NaN
# 137              7.68889  ...            0.0             0.0             0.0
# 138              5.14286  ...            0.0             0.0             0.0
# 151              11.3333  ...           75.0             0.0             0.0
# 170              9.52542  ...           20.0             0.0             0.0
# 171              9.52542  ...           20.0             0.0             0.0
# 194              10.3333  ...            0.0             0.0             0.0
# 257                    8  ...            0.0             0.0             0.0
# 263                  NaN  ...            NaN             NaN             NaN
# 266                  NaN  ...            0.0             0.0             0.0
# 278              8.76471  ...            0.0             0.0             0.0
# 310                    7  ...           15.0             0.0             0.0
# ...                  ...  ...            ...             ...             ...
# 28432                NaN  ...            0.0             0.0             0.0
# 28433                NaN  ...            0.0             0.0             0.0
# 28434                NaN  ...            0.0             0.0             0.0
# 28435                NaN  ...            0.0             0.0             0.0
# 28436                NaN  ...            0.0             0.0             0.0
# 28437                NaN  ...            0.0             0.0             0.0
# 28438                NaN  ...            0.0             0.0             0.0
# 28439                NaN  ...            0.0             0.0             0.0
# 28440                NaN  ...            0.0             0.0             0.0
# 28441                NaN  ...            0.0             0.0             0.0
# 28442                NaN  ...            0.0             0.0             0.0
# 28443                NaN  ...            0.0             0.0             0.0
# 28444                NaN  ...            0.0             0.0             0.0
# 28445                NaN  ...            0.0             0.0             0.0
# 28446                NaN  ...            0.0             0.0             0.0
# 28447                NaN  ...            0.0             0.0             0.0
# 28448                NaN  ...            0.0             0.0             0.0
# 28449                NaN  ...            0.0             0.0             0.0
# 28450                NaN  ...            0.0             0.0             0.0
# 28451                NaN  ...            0.0             0.0             0.0
# 28452                NaN  ...            0.0             0.0             0.0
# 28453                NaN  ...            0.0             0.0             0.0
# 28454                NaN  ...            0.0             0.0             0.0
# 28455                NaN  ...            0.0             0.0             0.0
# 28456                NaN  ...            0.0             0.0             0.0
# 28457                NaN  ...            0.0             0.0             0.0
# 28458                NaN  ...            0.0             0.0             0.0
# 28459                NaN  ...            0.0             0.0             0.0
# 28460                NaN  ...            0.0             0.0             0.0
# 28461                NaN  ...            0.0             0.0             0.0
#
#       Practical Training_edit Praksishold_edit Tutoring_edit Manuduktion_edit  \
# 21                        0.0              0.0           0.0              0.0
# 27                        NaN              NaN           NaN              NaN
# 33                        NaN              NaN           NaN              NaN
# 34                        NaN              NaN           NaN              NaN
# 35                        NaN              NaN           NaN              NaN
# 40                        NaN              NaN           NaN              NaN
# 41                        NaN              NaN           NaN              NaN
# 42                        NaN              NaN           NaN              NaN
# 43                        0.0              0.0           0.0              0.0
# 44                        0.0              0.0           0.0              0.0
# 45                        0.0              0.0           0.0              0.0
# 46                        0.0              0.0           0.0              0.0
# 47                        0.0              0.0           0.0              0.0
# 59                        0.0              0.0           0.0              0.0
# 81                        NaN              NaN           NaN              NaN
# 87                        0.0              0.0           0.0              0.0
# 89                        0.0              0.0           0.0              0.0
# 115                       NaN              NaN           NaN              NaN
# 116                       NaN              NaN           NaN              NaN
# 137                       0.0              0.0           0.0              0.0
# 138                       0.0              0.0           0.0              0.0
# 151                       0.0              0.0           0.0              0.0
# 170                       0.0              0.0           0.0              0.0
# 171                       0.0              0.0           0.0              0.0
# 194                       0.0              0.0           0.0              0.0
# 257                       0.0              0.0           0.0              0.0
# 263                       NaN              NaN           NaN              NaN
# 266                       0.0              0.0           0.0              0.0
# 278                       0.0              0.0           0.0              0.0
# 310                       0.0              0.0           0.0              0.0
# ...                       ...              ...           ...              ...
# 28432                     0.0              0.0           0.0              0.0
# 28433                     0.0              0.0           0.0              0.0
# 28434                     0.0              0.0           0.0              0.0
# 28435                     0.0              0.0           0.0              0.0
# 28436                     0.0              0.0           0.0              0.0
# 28437                     0.0              0.0           0.0              0.0
# 28438                     0.0              0.0           0.0              0.0
# 28439                     0.0              0.0           0.0              0.0
# 28440                     0.0              0.0           0.0              0.0
# 28441                     0.0              0.0           0.0              0.0
# 28442                     0.0              0.0           0.0              0.0
# 28443                     0.0              0.0           0.0              0.0
# 28444                     0.0              0.0           0.0              0.0
# 28445                     0.0              0.0           0.0              0.0
# 28446                     0.0              0.0           0.0              0.0
# 28447                     0.0              0.0           0.0              0.0
# 28448                     0.0              0.0           0.0              0.0
# 28449                     0.0              0.0           0.0              0.0
# 28450                     0.0              0.0           0.0              0.0
# 28451                     0.0              0.0           0.0              0.0
# 28452                     0.0              0.0           0.0              0.0
# 28453                     0.0              0.0           0.0              0.0
# 28454                     0.0              0.0           0.0              0.0
# 28455                     0.0              0.0           0.0              0.0
# 28456                     0.0              0.0           0.0              0.0
# 28457                     0.0              0.0           0.0              0.0
# 28458                     0.0              0.0           0.0              0.0
# 28459                     0.0              0.0           0.0              0.0
# 28460                     0.0              0.0           0.0              0.0
# 28461                     0.0              0.0           0.0              0.0
#
#       Language_edit            Type of assessmet_edit  \
# 21           Danish                         Portfolio
# 27              NaN                               NaN
# 33              NaN                               NaN
# 34              NaN                               NaN
# 35              NaN                               NaN
# 40              NaN                               NaN
# 41              NaN                               NaN
# 42              NaN                               NaN
# 43          English    Written not under invigilation
# 44          English    Written not under invigilation
# 45          English    Written not under invigilation
# 46          English    Written not under invigilation
# 47          English    Written not under invigilation
# 59          English                         Portfolio
# 81              NaN                               NaN
# 87           Danish    Written not under invigilation
# 89           Danish    Written not under invigilation
# 115             NaN                               NaN
# 116             NaN                               NaN
# 137         English                              Oral
# 138         English                              Oral
# 151         English    Written not under invigilation
# 170         English                              Oral
# 171         English                              Oral
# 194         English                              Oral
# 257         English                              Oral
# 263             NaN                               NaN
# 266         English      Course participation written
# 278         English                              Oral
# 310         English                              Oral
# ...             ...                               ...
# 28432        Danish    Written not under invigilation
# 28433        Danish                              Oral
# 28434        Danish    Written not under invigilation
# 28435        Danish    Written not under invigilation
# 28436        Danish    Written not under invigilation
# 28437        Danish    Written not under invigilation
# 28438        Danish    Written not under invigilation
# 28439        Danish    Written not under invigilation
# 28440        Danish    Written not under invigilation
# 28441        Danish    Written not under invigilation
# 28442        Danish    Written not under invigilation
# 28443        Danish    Written not under invigilation
# 28444        Danish    Written not under invigilation
# 28445        Danish    Written not under invigilation
# 28446        Danish    Written not under invigilation
# 28447        Danish    Written not under invigilation
# 28448        Danish    Written not under invigilation
# 28449        Danish    Written not under invigilation
# 28450        Danish    Written not under invigilation
# 28451        Danish  Course participation not written
# 28452        Danish    Written not under invigilation
# 28453        Danish    Written not under invigilation
# 28454        Danish                             Other
# 28455        Danish    Written not under invigilation
# 28456        Danish    Written not under invigilation
# 28457        Danish    Written not under invigilation
# 28458        Danish    Written not under invigilation
# 28459        Danish    Written not under invigilation
# 28460        Danish    Written not under invigilation
# 28461        Danish    Written not under invigilation
#
#                                                    URL_C
# 21     https://kurser.ku.dk/archive/2013-2014/course/...
# 27                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 35                                                   NaN
# 40                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 43     https://kurser.ku.dk/archive/2013-2014/course/...
# 44     https://kurser.ku.dk/archive/2013-2014/course/...
# 45     https://kurser.ku.dk/archive/2013-2014/course/...
# 46     https://kurser.ku.dk/archive/2013-2014/course/...
# 47     https://kurser.ku.dk/archive/2013-2014/course/...
# 59     https://kurser.ku.dk/archive/2013-2014/course/...
# 81                                                   NaN
# 87     https://kurser.ku.dk/archive/2013-2014/course/...
# 89     https://kurser.ku.dk/archive/2013-2014/course/...
# 115                                                  NaN
# 116                                                  NaN
# 137    https://kurser.ku.dk/archive/2013-2014/course/...
# 138    https://kurser.ku.dk/archive/2013-2014/course/...
# 151    https://kurser.ku.dk/archive/2013-2014/course/...
# 170    https://kurser.ku.dk/archive/2013-2014/course/...
# 171    https://kurser.ku.dk/archive/2013-2014/course/...
# 194    https://kurser.ku.dk/archive/2013-2014/course/...
# 257    https://kurser.ku.dk/archive/2013-2014/course/...
# 263                                                  NaN
# 266    https://kurser.ku.dk/archive/2013-2014/course/...
# 278    https://kurser.ku.dk/archive/2013-2014/course/...
# 310    https://kurser.ku.dk/archive/2013-2014/course/...
# ...                                                  ...
# 28432  https://kurser.ku.dk/archive/2013-2014/course/...
# 28433  https://kurser.ku.dk/archive/2013-2014/course/...
# 28434  https://kurser.ku.dk/archive/2013-2014/course/...
# 28435  https://kurser.ku.dk/archive/2013-2014/course/...
# 28436  https://kurser.ku.dk/archive/2013-2014/course/...
# 28437  https://kurser.ku.dk/archive/2013-2014/course/...
# 28438  https://kurser.ku.dk/archive/2013-2014/course/...
# 28439  https://kurser.ku.dk/archive/2013-2014/course/...
# 28440  https://kurser.ku.dk/archive/2013-2014/course/...
# 28441  https://kurser.ku.dk/archive/2013-2014/course/...
# 28442  https://kurser.ku.dk/archive/2013-2014/course/...
# 28443  https://kurser.ku.dk/archive/2013-2014/course/...
# 28444  https://kurser.ku.dk/archive/2013-2014/course/...
# 28445  https://kurser.ku.dk/archive/2013-2014/course/...
# 28446  https://kurser.ku.dk/archive/2013-2014/course/...
# 28447  https://kurser.ku.dk/archive/2013-2014/course/...
# 28448  https://kurser.ku.dk/archive/2013-2014/course/...
# 28449  https://kurser.ku.dk/archive/2013-2014/course/...
# 28450  https://kurser.ku.dk/archive/2013-2014/course/...
# 28451  https://kurser.ku.dk/archive/2013-2014/course/...
# 28452  https://kurser.ku.dk/archive/2013-2014/course/...
# 28453  https://kurser.ku.dk/archive/2013-2014/course/...
# 28454  https://kurser.ku.dk/archive/2013-2014/course/...
# 28455  https://kurser.ku.dk/archive/2013-2014/course/...
# 28456  https://kurser.ku.dk/archive/2013-2014/course/...
# 28457  https://kurser.ku.dk/archive/2013-2014/course/...
# 28458  https://kurser.ku.dk/archive/2013-2014/course/...
# 28459  https://kurser.ku.dk/archive/2013-2014/course/...
# 28460  https://kurser.ku.dk/archive/2013-2014/course/...
# 28461  https://kurser.ku.dk/archive/2013-2014/course/...
#
# [4812 rows x 120 columns]

# %%
dfo[dfo['URL_E'] == 'http://karakterstatistik.stads.ku.dk/Histogram/HEEK03471E/Summer-2018' ][]
# Out:
#                    Kursus                   Fakultet  \
# 13307  Kultur og historie  Det Humanistiske Fakultet
#
#                                                 Institut Termin ECTS  \
# 13307  Saxo-Instituttet - Arkæologi, Etnologi, Histor...    s18   15
#
#           Eksamenstype Antal tilmeldte Fremmødte Antal bestået  \
# 13307  Ordinær eksamen              19        17            15
#
#       Eksamensgennemsnit  ... Colloquia_edit Laboratory_edit E-Learning_edit  \
# 13307            8.70588  ...            NaN             NaN             NaN
#
#       Practical Training_edit Praksishold_edit Tutoring_edit Manuduktion_edit  \
# 13307                     NaN              NaN           NaN              NaN
#
#       Language_edit Type of assessmet_edit URL_C
# 13307           NaN                    NaN   NaN
#
# [1 rows x 120 columns]
