# %% [markdown]
# ## Merching course website with grade stats

# %%
import scraping_class
logfile = 'log.txt'## name your log file.
connector = scraping_class.Connector(logfile)
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook

# %%
import pandas as pd
import numpy as np
import html5lib
import sys

# %%
df = pd.read_pickle('grade_scrabe_3k.pkl')
df
# Out:
#                      0                                                  1  \
# 0               Kursus   Numerical methods in atmospheric and oceanic ...
# 1             Fakultet           Det Natur- og Biovidenskabelige Fakultet
# 2             Institut                              Niels Bohr Institutet
# 3               Termin                                             s15/B3
# 4                 ECTS                                                 75
# 5         Eksamenstype                                    Ordinær eksamen
# 6      Antal tilmeldte                                                 16
# 7            Fremmødte                                                 14
# 8        Antal bestået                                                 14
# 9   Eksamensgennemsnit                                            7.85714
# 10                  12                                                  3
# 11                  10                                                  2
# 12                   7                                                  6
# 13                   4                                                  3
# 14                   2                                                  0
# 15                   0                                                  0
# 16                  -3                                                  0
# 17             Ej mødt                                                  2
# 18        Ikke bestået                                                NaN
#
#     re 1                                    2  \
# 0    NaN           Toxicology and Drug Safety
# 1    NaN  Det Sundhedsvidenskabelige Fakultet
# 2    NaN                              Farmaci
# 3    NaN                               v18/B1
# 4    NaN                                    5
# 5    NaN                      Ordinær eksamen
# 6    NaN                                  163
# 7    NaN                                  160
# 8    NaN                                  144
# 9    NaN                              5.53125
# 10   NaN                                    3
# 11   NaN                                   35
# 12   NaN                                   44
# 13   NaN                                   38
# 14   NaN                                   24
# 15   NaN                                   13
# 16   NaN                                    3
# 17   NaN                                    3
# 18   NaN                                  NaN
#
#                                    re 2   3  re 3   4  re 4   5  ...  \
# 0            Toxicology and Drug Safety NaN   NaN NaN   NaN NaN  ...
# 1   Det Sundhedsvidenskabelige Fakultet NaN   NaN NaN   NaN NaN  ...
# 2                               Farmaci NaN   NaN NaN   NaN NaN  ...
# 3                                v18/B1 NaN   NaN NaN   NaN NaN  ...
# 4                                     5 NaN   NaN NaN   NaN NaN  ...
# 5                             Reeksamen NaN   NaN NaN   NaN NaN  ...
# 6                                    16 NaN   NaN NaN   NaN NaN  ...
# 7                                    16 NaN   NaN NaN   NaN NaN  ...
# 8                                    13 NaN   NaN NaN   NaN NaN  ...
# 9                                 2.375 NaN   NaN NaN   NaN NaN  ...
# 10                                    0 NaN   NaN NaN   NaN NaN  ...
# 11                                    1 NaN   NaN NaN   NaN NaN  ...
# 12                                    0 NaN   NaN NaN   NaN NaN  ...
# 13                                    2 NaN   NaN NaN   NaN NaN  ...
# 14                                   10 NaN   NaN NaN   NaN NaN  ...
# 15                                    3 NaN   NaN NaN   NaN NaN  ...
# 16                                    0 NaN   NaN NaN   NaN NaN  ...
# 17                                  NaN NaN   NaN NaN   NaN NaN  ...
# 18                                  NaN NaN   NaN NaN   NaN NaN  ...
#
#                                              3329  re 3329  3330  re 3330  \
# 0                            Byens grønne områder      NaN   NaN      NaN
# 1        Det Natur- og Biovidenskabelige Fakultet      NaN   NaN      NaN
# 2   Institut for Geovidenskab og Naturforvaltning      NaN   NaN      NaN
# 3                                          v14/B2      NaN   NaN      NaN
# 4                                              75      NaN   NaN      NaN
# 5                                 Ordinær eksamen      NaN   NaN      NaN
# 6                                              46      NaN   NaN      NaN
# 7                                              46      NaN   NaN      NaN
# 8                                              46      NaN   NaN      NaN
# 9                                         9.65217      NaN   NaN      NaN
# 10                                             16      NaN   NaN      NaN
# 11                                             17      NaN   NaN      NaN
# 12                                             10      NaN   NaN      NaN
# 13                                              3      NaN   NaN      NaN
# 14                                              0      NaN   NaN      NaN
# 15                                              0      NaN   NaN      NaN
# 16                                              0      NaN   NaN      NaN
# 17                                            NaN      NaN   NaN      NaN
# 18                                            NaN      NaN   NaN      NaN
#
#     3331  re 3331  3332  re 3332  3333  re 3333
# 0    NaN      NaN   NaN      NaN   NaN      NaN
# 1    NaN      NaN   NaN      NaN   NaN      NaN
# 2    NaN      NaN   NaN      NaN   NaN      NaN
# 3    NaN      NaN   NaN      NaN   NaN      NaN
# 4    NaN      NaN   NaN      NaN   NaN      NaN
# 5    NaN      NaN   NaN      NaN   NaN      NaN
# 6    NaN      NaN   NaN      NaN   NaN      NaN
# 7    NaN      NaN   NaN      NaN   NaN      NaN
# 8    NaN      NaN   NaN      NaN   NaN      NaN
# 9    NaN      NaN   NaN      NaN   NaN      NaN
# 10   NaN      NaN   NaN      NaN   NaN      NaN
# 11   NaN      NaN   NaN      NaN   NaN      NaN
# 12   NaN      NaN   NaN      NaN   NaN      NaN
# 13   NaN      NaN   NaN      NaN   NaN      NaN
# 14   NaN      NaN   NaN      NaN   NaN      NaN
# 15   NaN      NaN   NaN      NaN   NaN      NaN
# 16   NaN      NaN   NaN      NaN   NaN      NaN
# 17   NaN      NaN   NaN      NaN   NaN      NaN
# 18   NaN      NaN   NaN      NaN   NaN      NaN
#
# [19 rows x 6667 columns]

# %%
df = pd.DataFrame.from_dict(dict_load, orient='index')
